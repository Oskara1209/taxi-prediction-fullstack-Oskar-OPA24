# %%
import joblib
from taxipred.utils.constants import MODELS_PATH
clf = joblib.load(MODELS_PATH)
clf
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
from taxipred.utils.constants import CLEAN_TAXI_CSV_PATH
import pandas as pd

df = pd.read_csv(CLEAN_TAXI_CSV_PATH)
df.head()
# Out:
#    trip_distance_km time_of_day day_of_week  passenger_count  \
# 0             19.35     Morning     Weekday              3.0
# 1             36.87     Evening     Weekend              1.0
# 2             30.33     Evening     Weekday              4.0
# 3              8.64   Afternoon     Weekend              2.0
# 4              3.85   Afternoon     Weekday              4.0
#
#   traffic_conditions weather  base_fare  per_km_rate  per_minute_rate  \
# 0                Low   Clear       3.56         0.80             0.32
# 1               High   Clear       2.70         1.21             0.15
# 2                Low   Clear       3.48         0.51             0.15
# 3             Medium   Clear       2.55         1.71             0.48
# 4               High    Rain       3.51         1.66             0.29
#
#    trip_duration_minutes  trip_price
# 0                  53.82     36.2624
# 1                  37.27     52.9032
# 2                 116.81     36.4698
# ...

# %%
df.describe().T
# Out:
#                        count       mean        std     min        25%  \
# trip_distance_km       858.0  27.226538  20.412070  1.2300  12.440000
# passenger_count        858.0   2.458042   1.075336  1.0000   2.000000
# base_fare              858.0   3.510653   0.853539  2.0100   2.760000
# per_km_rate            858.0   1.234021   0.418955  0.5000   0.872500
# per_minute_rate        858.0   0.292494   0.111788  0.1000   0.200000
# trip_duration_minutes  858.0  62.177343  32.296128  5.0100  35.600000
# trip_price             858.0  57.445364  41.869913  6.1269  33.772875
#
#                            50%        75%         max
# trip_distance_km       25.7750  38.702500  146.067047
# passenger_count         2.0000   3.000000    4.000000
# base_fare               3.5400   4.210000    5.000000
# per_km_rate             1.2200   1.580000    2.000000
# per_minute_rate         0.2900   0.380000    0.500000
# trip_duration_minutes  61.9450  89.210000  119.840000
# ...

# %%
import pandas as pd 

sample_test_data = pd.DataFrame([{"trip_distance_km": 20, "trip_duration_minutes": 60, "per_km_rate": 0.30, "per_minute_rate": 0.80, "base_fare": 4}])
sample_test_data
# Out:
#    trip_distance_km  trip_duration_minutes  per_km_rate  per_minute_rate  \
# 0                20                     60          0.3              0.8
#
#    base_fare
# 0          4

# %%
clf.predict(sample_test_data)
# Out:
# array([43.98944223])

# %%
clf.predict(sample_test_data)[0]
# Out:
# np.float64(43.98944223399184)
